# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeldana13/VisualizeData/blob/master/krisha2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at drive

# %%
df = pd.read_csv("/content/drive/My Drive/apartments.csv")
#print(df)
type(df)
df.head()
# Out:
#   amount  area  floor    price                 city            region
# 0      1  45.0    3/5   95 000               Алматы   Алмалинский р-н
# 1      2  67.0   6/10  150 000  Нур-Султан (Астана)     Есильский р-н
# 2      3  49.0    3/4   80 000               Алматы    Ауэзовский р-н
# 3      4  42.0    2/5  150 000               Алматы   Алмалинский р-н
# 4      5  47.0  10/16  160 000  Нур-Султан (Астана)      р-н Байконур

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9988 entries, 0 to 9987
# Data columns (total 6 columns):
# amount    9988 non-null object
# area      9986 non-null float64
# floor     9986 non-null object
# price     9986 non-null object
# city      9986 non-null object
# region    9986 non-null object
# dtypes: float64(1), object(5)
# memory usage: 468.3+ KB

# %%
df['area'] = pd.to_numeric(df['area'], errors='coerce')
df = df.dropna(subset=['area'])
df['area'] = df['area'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9986 entries, 0 to 9987
# Data columns (total 6 columns):
# amount    9986 non-null object
# area      9986 non-null float64
# floor     9986 non-null object
# price     9986 non-null object
# city      9986 non-null object
# region    9986 non-null object
# dtypes: float64(1), object(5)
# memory usage: 546.1+ KB

# %%
df['floor'] = pd.to_numeric(df['floor'], errors='coerce')
df['floor'] = df['floor'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9986 entries, 0 to 9987
# Data columns (total 6 columns):
# amount    9986 non-null object
# area      9986 non-null float64
# floor     972 non-null float64
# price     9986 non-null object
# city      9986 non-null object
# region    9986 non-null object
# dtypes: float64(2), object(4)
# memory usage: 546.1+ KB

# %%
df['amount'] = pd.to_numeric(df['amount'], errors='coerce')
#df = df.dropna(subset=['amount'])
df['amount'] = df['amount'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9986 entries, 0 to 9987
# Data columns (total 6 columns):
# amount    9986 non-null int64
# area      9986 non-null float64
# floor     972 non-null float64
# price     9986 non-null object
# city      9986 non-null object
# region    9986 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 546.1+ KB

# %%
import pandas as pd
import numpy as np
from google.colab import drive
from matplotlib import pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(16, 6))
df[df['area']<40].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9fc218b00>,
# ...
#       dtype=object)

# %%
sns.heatmap(df.corr())

# %%
np.random.seed(19680801)
plt.figure(figsize=(16, 14))

x = df['city'].iloc[:500]
y = df['price'].iloc[:500]
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x, y,  c="g", alpha=0.5, 
            label="city/price")
plt.xticks(rotation=90)
plt.xlabel("city")
plt.ylabel("price for rent(tg)")
plt.legend(loc='upper left')
plt.show()

# %%
np.random.seed(19680801)
plt.figure(figsize=(16, 12))

x = df['area'].iloc[:500]
y = df['price'].iloc[:500]
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x, y,  c="g", alpha=0.5, 
            label="area/price")


plt.xlabel("area(m^2) first 500 el-s")
plt.ylabel("price for rent(tg)")
plt.legend(loc='upper left')
plt.show()

# %%
df.groupby(df['city'])

# %%
plt.figure(figsize=(16, 6))
plt.xlabel("region")
plt.ylabel("price for rent in(tg)")
plt.xticks(rotation=90)
plt.scatter(df['region'].iloc[:50], df['price'].iloc[:50], label='linear')

# %%
plt.figure(figsize=(20, 6))
plt.xlabel("region")
plt.ylabel("amount")
plt.xticks(rotation=90)
plt.bar(df['region'].iloc[:500], df['amount'].iloc[:500])
# Out:
# <BarContainer object of 500 artists>
